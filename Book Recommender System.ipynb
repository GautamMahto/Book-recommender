# %% [markdown]
# # Book Recommender System

# %% [markdown]
# #### by Gautam Mahto

# %% [markdown]
# ## Import Essential Libraries

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Import Datasets

# %%
book1=pd.read_csv('C:\\Users\\GAUTAM\\Desktop\\Recommender System\\dataset\\books.csv')
book2=pd.read_csv('C:\\Users\\GAUTAM\\Desktop\\Recommender System\\dataset\\books_new.csv')

# %% [markdown]
# ### look the shape and head of the DataFrame

# %%
book1.shape
# Out:
# (211, 5)

# %%
book2.shape
# Out:
# (211, 6)

# %%
book1.head()
# Out:
#                       Title            Author              Genre  Height  \
# 0  Fundamentals of Wavelets  Goswami, Jaideva  signal_processing     228
# 1                Data Smart     Foreman, John       data_science     235
# 2  God Created the Integers  Hawking, Stephen        mathematics     197
# 3         Superfreakonomics   Dubner, Stephen          economics     179
# 4               Orientalism      Said, Edward            history     197
#
#        Publisher
# 0          Wiley
# 1          Wiley
# 2        Penguin
# 3  HarperCollins
# 4        Penguin

# %%
book2.head()
# Out:
#                       Title            Author       Genre           SubGenre  \
# 0  Fundamentals of Wavelets  Goswami, Jaideva        tech  signal_processing
# 1                Data Smart     Foreman, John        tech       data_science
# 2  God Created the Integers  Hawking, Stephen        tech        mathematics
# 3         Superfreakonomics   Dubner, Stephen     science          economics
# 4               Orientalism      Said, Edward  nonfiction            history
#
#    Height      Publisher
# 0     228          Wiley
# 1     235          Wiley
# 2     197        Penguin
# 3     179  HarperCollins
# 4     197        Penguin

# %% [markdown]
# ### Here We conclude that book 1 and book 2 has same no of rows and values but book2 has one different column so for the data Preprocessing we will take book2 as a main DataFrame

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
book2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      211 non-null    object
#  1   Author     187 non-null    object
#  2   Genre      211 non-null    object
#  3   SubGenre   211 non-null    object
#  4   Height     211 non-null    int64
#  5   Publisher  115 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 10.0+ KB

# %% [markdown]
# ### we will drop that columns which are not necessary

# %%
book2.drop(columns=['Publisher','Height'],inplace=True)

# %%
book2.isnull().sum()
# Out:
# Title        0
# Author      24
# Genre        0
# SubGenre     0
# dtype: int64

# %% [markdown]
# Drop the null Values

# %%
book2.dropna(inplace=True)

# %%
book2.isnull().sum()
# Out:
# Title       0
# Author      0
# Genre       0
# SubGenre    0
# dtype: int64

# %% [markdown]
# Reset the Index

# %%
book2.reset_index(drop=True,inplace=True)

# %% [markdown]
# ## here values are not in the systematic Form so we will convert into the Systematic form

# %%
new_lst=[]
for i in book2['Author']:
    if(',' in i):
        name = i
        parts = name.split(", ")
        new_name = "{} {}".format(parts[1], parts[0])
        new_lst.append(new_name)
    else:
        new_lst.append(i)

# %%
book2['Author']=new_lst

# %%
new_lst=[]
for i in book2['Title']:
    if(',' in i):
        name = i
        parts = name.split(", ")
        new_name = "{} {}".format(parts[1], parts[0])
        new_lst.append(new_name)
    else:
        new_lst.append(i)

# %%
book2['Title']=new_lst

# %%
book2.head()
# Out:
#                       Title           Author       Genre           SubGenre
# 0  Fundamentals of Wavelets  Jaideva Goswami        tech  signal_processing
# 1                Data Smart     John Foreman        tech       data_science
# 2  God Created the Integers  Stephen Hawking        tech        mathematics
# 3         Superfreakonomics   Stephen Dubner     science          economics
# 4               Orientalism      Edward Said  nonfiction            history

# %%
book2
# Out:
#                                                  Title                 Author  \
# 0                             Fundamentals of Wavelets        Jaideva Goswami
# 31      fiction              novel
# 32   nonfiction      autobiography
# 33      science            physics
# 34      science            physics
# 35      fiction            classic
# 36      fiction              novel
# 37      fiction              novel
# 38   nonfiction      autobiography
# 39   philosophy        objectivism
# 40      fiction              novel
# 41   nonfiction            history
# 42      fiction            classic
# 43      science          economics
# 44      science            physics
# 45   philosophy            history
# 46      fiction              novel
# 47      fiction            classic
# 48   nonfiction            history
# 49      fiction            classic
# 50      fiction              novel
# 51      fiction              novel
# 52      fiction            classic
# 53   nonfiction             trivia
# 54   nonfiction      autobiography
# 55         tech       data_science
# 56         tech          economics
# 57         tech          economics
# 58         tech  signal_processing
# 59         tech   computer_science
# 60         tech  signal_processing
# 61         tech  signal_processing
# 62         tech   computer_science
# 63      fiction              novel
# 64      fiction            classic
# 65      fiction              novel
# 66   nonfiction            history
# 67      fiction              novel
# 68   philosophy          economics
# 69      fiction              novel
# 70   nonfiction            history
# 71      fiction              novel
# 72   nonfiction            history
# 73   nonfiction      autobiography
# 74   nonfiction            history
# 75         tech          economics
# 76   nonfiction               misc
# 77   nonfiction               misc
# 78   nonfiction               misc
# 79   nonfiction             poetry
# 80   nonfiction               misc
# 81   nonfiction            history
# 82      fiction              novel
# 83   nonfiction            history
# 84      fiction              novel
# 85   nonfiction            history
# 86      fiction            classic
# 87   philosophy          education
# 88   nonfiction         psychology
# 89   nonfiction            history
# 90      fiction              novel
# 91      science            physics
# 92      science          economics
# 93      science            physics
# 94      fiction            classic
# 95      fiction            classic
# 96   nonfiction          economics
# 97      fiction              novel
# 98   nonfiction      autobiography
# 99   philosophy         philosophy
# 100  nonfiction            history
# 101  nonfiction      autobiography
# 102     fiction            classic
# 103     fiction            classic
# 104     fiction            classic
# 105  philosophy      autobiography
# 106  nonfiction            history
# 107     fiction              novel
# 108     science        mathematics
# 109  philosophy         philosophy
# 110     science          economics
# 111  nonfiction            history
# 112  nonfiction          anthology
# 113  nonfiction      autobiography
# 114     fiction            classic
# 115     fiction              novel
# 116  nonfiction            history
# 117  nonfiction               misc
# 118  philosophy         philosophy
# 119     fiction              novel
# 120  nonfiction            history
# 121  nonfiction               misc
# 122     fiction              novel
# 123     fiction            classic
# 124  nonfiction            history
# 125     fiction              novel
# 126     fiction              novel
# 127     science        mathematics
# 128        tech       data_science
# 129  nonfiction            history
# 130     science        mathematics
# 131  nonfiction            history
# 132     science        mathematics
# 133  nonfiction      autobiography
# 134     science        mathematics
# 135        tech  signal_processing
# 136        tech   computer_science
# 137        tech   computer_science
# 138        tech       data_science
# 139     fiction            classic
# 140  nonfiction               misc
# 141        tech       data_science
# 142  nonfiction            history
# 143  nonfiction            history
# 144  nonfiction            history
# 145  nonfiction            history
# 146  nonfiction            history
# 147  nonfiction            history
# 148  nonfiction            history
# 149     fiction              novel
# 150     fiction              novel
# 151     fiction              novel
# 152     fiction              novel
# 153        tech   computer_science
# 154        tech   computer_science
# 155        tech   computer_science
# 156        tech       data_science
# 157     fiction              novel
# 158  philosophy        objectivism
# 159  philosophy        objectivism
# 160        tech       data_science
# 161     science            physics
# 162     science        mathematics
# 163     science            science
# 164  nonfiction              legal
# 165  philosophy         philosophy
# 166  philosophy         philosophy
# 167  philosophy         philosophy
# 168  nonfiction      autobiography
# 169  nonfiction            history
# 170  nonfiction            history
# 171  nonfiction            history
# 172  nonfiction              legal
# 173     fiction              novel
# 174     fiction              novel
# 175     fiction              novel
# 176     fiction            classic
# 177     fiction              novel
# 178     fiction              novel
# 179     fiction              novel
# 180     fiction              novel
# 181     fiction              novel
# 182     science        mathematics
# 183        tech  signal_processing
# 184     fiction            classic
# 185     fiction            classic
# 186     fiction            classic

# %% [markdown]
# ### Here we will Convert the string obj into the List

# %%
def convert(text):
    l=[text]
    return l

# %%
column_lst=['Author','Genre','SubGenre']

# %%
for i in column_lst:
    book2[i]=book2[i].apply(convert)

# %%
book2.head()
# Out:
#                       Title             Author         Genre  \
# 0  Fundamentals of Wavelets  [Jaideva Goswami]        [tech]
# 1                Data Smart     [John Foreman]        [tech]
# 2  God Created the Integers  [Stephen Hawking]        [tech]
# 3         Superfreakonomics   [Stephen Dubner]     [science]
# 4               Orientalism      [Edward Said]  [nonfiction]
#
#               SubGenre
# 0  [signal_processing]
# 1       [data_science]
# 2        [mathematics]
# 3          [economics]
# 4            [history]

# %% [markdown]
# ### here we will create the tag column

# %%
book2['Tag']=book2['Author']+book2['Genre']+book2['SubGenre']

# %% [markdown]
# ### Here we will crearte the new dataframe with necessary  columns

# %%
new_df=book2.drop(columns=['Author','Genre','SubGenre'])

# %%
new_df['Tag'] = new_df['Tag'].apply(lambda x: " ".join(x))
new_df.head()
# Out:
#                       Title                                     Tag
# 0  Fundamentals of Wavelets  Jaideva Goswami tech signal_processing
# 1                Data Smart          John Foreman tech data_science
# 2  God Created the Integers        Stephen Hawking tech mathematics
# 3         Superfreakonomics        Stephen Dubner science economics
# 4               Orientalism          Edward Said nonfiction history

# %% [markdown]
# ### here we will perform CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=200,stop_words='english')

# %%
cv.get_feature_names()
# Out:
# C:\Users\GAUTAM\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['abraham',
#  'ackroyd',
#  'aczel',
#  'adam',
#  'adolf',
#  'albert',
#  'aldous',
#  'alex',
#  'alfred',
#  'allen',
#  'amartya',
#  'amir',
#  'amitav',
#  'andrew',
#  'andy',
#  'anthology',
#  'archer',
#  'arthur',
#  'autobiography',
#  'ayn',
#  'bach',
#  'baz',
#  'bbc',
#  'bell',
#  'bertrand',
#  'bob',
#  'bodanis',
#  'bradsky',
#  'braithwaite',
#  'brown',
#  'camus',
#  'capra',
#  'carl',
#  'cedric',
#  'charles',
#  'classic',
#  'computer_science',
#  'conan',
#  'conway',
#  'corbett',
#  'cormen',
#  'crichton',
#  'dalrymple',
#  'dan',
#  'data_science',
#  'david',
#  'dawkins',
#  'deb',
#  'deshpande',
#  'devlin',
#  'dickens',
#  'dickinson',
#  'dominique',
#  'dostoevsky',
#  'downey',
#  'doyle',
#  'drew',
#  'drucker',
#  'dubner',
#  'duda',
#  'durant',
#  'durrell',
#  'dylan',
#  'earle',
#  'economics',
#  'eddins',
#  'edgar',
#  'education',
#  'edward',
#  'eraly',
#  'eric',
#  'ernest',
#  'feynman',
#  'fiction',
#  'fisk',
#  'follett',
#  'foreman',
#  'forsyth',
#  'frank',
#  'frederick',
#  'fritjof',
#  'fyodor',
#  'george',
#  'gerald',
#  'gordon',
#  'hawking',
#  'history',
#  'jaideva',
#  'james',
#  'janert',
#  'jawaharlal',
#  'jean',
#  'jeffery',
#  'jim',
#  'john',
#  'jonathan',
#  'joseph',
#  'kanetkar',
#  'lapierre',
#  'larsson',
#  'legal',
#  'lorraine',
#  'madan',
#  'maria',
#  'mathematics',
#  'maugham',
#  'mckinney',
#  'menon',
#  'michael',
#  'misc',
#  'mlodinow',
#  'mohan',
#  'morris',
#  'muhammad',
#  'naipaul',
#  'nariman',
#  'nate',
#  'nayar',
#  'ned',
#  'nehru',
#  'nisbet',
#  'nonfiction',
#  'novel',
#  'objectivism',
#  'oram',
#  'orwell',
#  'palkhivala',
#  'pausch',
#  'peter',
#  'phillip',
#  'philosophy',
#  'physics',
#  'pirsig',
#  'poe',
#  'poetry',
#  'pratt',
#  'psychology',
#  'rand',
#  'randy',
#  'ranjan',
#  'rashid',
#  'raymond',
#  'richard',
#  'robert',
#  'rowling',
#  'russell',
#  'rutherford',
#  'sagan',
#  'said',
#  'sam',
#  'samuel',
#  'sanjay',
#  'sassoon',
#  'schilling',
#  'science',
#  'sebastian',
#  'sen',
#  'sergio',
#  'shashi',
#  'shih',
#  'siddhartha',
#  'signal_processing',
#  'silver',
#  'simon',
#  'singh',
#  'smith',
#  'sorabjee',
#  'stanley',
#  'steig',
#  'steinbeck',
#  'stephen',
#  'steve',
#  'stonier',
#  'stroud',
#  'sudhanshu',
#  'sunita',
#  'sussman',
#  'tanenbaum',
#  'tao',
#  'taub',
#  'tech',
#  'terence',
#  'tharoor',
#  'thomas',
#  'trivia',
#  'vapnik',
#  'various',
#  'verne',
#  'victor',
#  'villani',
#  'vladimir',
#  'vonnegut',
#  'wells',
#  'werner',
#  'wes',
#  'west',
#  'william',
#  'woodward',
#  'yashwant',
#  'zaidi']

# %%
vector = cv.fit_transform(new_df['Tag']).toarray()

# %%
vector.shape
# Out:
# (187, 200)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.28867513, 0.28867513, ..., 0.        , 0.        ,
#         0.        ],
#        [0.28867513, 1.        , 0.25      , ..., 0.        , 0.        ,
#         0.        ],
#        [0.28867513, 0.25      , 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.5       ,
#         0.5       ],
#        [0.        , 0.        , 0.        , ..., 0.5       , 1.        ,
#         0.5       ],
#        [0.        , 0.        , 0.        , ..., 0.5       , 0.5       ,
#         1.        ]])

# %%
new_df[new_df['Title'] == 'Data Smart'].index[0]
# Out:
# 1

# %% [markdown]
# ### here we will Predict the output

# %%
def recommend(book,n):
    df = pd.DataFrame(columns=['Title', 'Author'])
    index = new_df[new_df['Title'] == book].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:n]:
        a=new_df.iloc[i[0]].Title
        b=book2.iloc[i[0]].Author
        df.loc[len(df)] = [a, b]
    return df

# %%
recommend('Python for Data Analysis',10)
# Out:
#                                        Title                 Author
# 0                    Data Scientists at Work  [Sebastian Gutierrez]
# 1       Soft Computing & Intelligent Systems          [Madan Gupta]
# 2                     Pattern Classification            [Hart Duda]
# 3                            Neural Networks         [Simon Haykin]
# 4                                 Data Smart         [John Foreman]
# 5  The Nature of Statistical Learning Theory      [Vladimir Vapnik]
# 6               Statistical Decision Theory'           [John Pratt]
# 7                       Data Mining Handbook        [Robert Nisbet]
# 8               Machine Learning for Hackers          [Drew Conway]

# %% [markdown]
# ### Import Pickle Module and Save the ML Model

# %%
import pickle
